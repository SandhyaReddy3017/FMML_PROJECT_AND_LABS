# %% [markdown]
# <a href="https://colab.research.google.com/github/SandhyaReddy3017/FMML_PROJECT_AND_LABS/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-04-12 01:54:05--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   134MB/s    in 0.5s
#
# 2024-04-12 01:54:09 (134 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 22481  1609.01423v3  Principal component analysis (PCA) is an explo...  stat
# 24851   1412.3506v2  Detecting traversable road areas ahead a movin...    cs
# 6475   1702.06899v1  liquidSVM is a package written in C++ that pro...  stat
# 37997   0910.0526v1  The Lasso is a very well known penalized regre...  stat
# 2399   1505.05004v2  We present a novel hybrid algorithm for Bayesi...  stat
# ...             ...                                                ...   ...
# 1237   1606.03498v1  We present a variety of new architectural feat...    cs
# 8228    1312.6594v3  In this paper, we investigate a new framework ...    cs
# 1842   1708.03052v1  Embarrassingly (communication-free) parallel M...    cs
# 17194  1709.03814v1  This paper describes SYSTRAN's systems submitt...    cs
# 6263   1610.06761v1  We present new methods for batch anomaly detec...  stat
#
#                                                    title  year  \
# 22481  Structured Sparse Principal Components Analysi...  2016
# 24851  Road Detection by One-Class Color Classificati...  2014
# 6475         liquidSVM: A Fast and Versatile SVM package  2017
# 37997  A path algorithm for the Fused Lasso Signal Ap...  2009
# 2399   An Experimental Comparison of Hybrid Algorithm...  2015
# ...                                                  ...   ...
# 1237               Improved Techniques for Training GANs  2016
# 8228   Sequentially Generated Instance-Dependent Imag...  2013
# 1842   Communication-Free Parallel Supervised Topic M...  2017
# 17194       SYSTRAN Purely Neural MT Engines for WMT2017  2017
# 6263   Maximally Divergent Intervals for Anomaly Dete...  2016
#
#                                                 keywords
# 22481  [principal, component, exploratory, variabilit...
# 24851  [detecting, traversable, autonomous, detection...
# 6475   [liquidsvm, classification, regression, integr...
# 37997  [penalized, regression, parameter, coefficient...
# 2399   [algorithm, structure, reconstructs, subroutin...
# ...                                                  ...
# 1237   [architectural, procedures, generative, advers...
# 8228   [investigate, framework, classification, adapt...
# 1842   [embarrassingly, graphical, ergodicity, multim...
# 17194  [describes, submitted, translation, translatio...
# 6263   [detection, multivariate, maximizing, divergen...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 22481    [principal, component, exploratory, variabilit...
# 24851    [detecting, traversable, autonomous, detection...
# 6475     [liquidsvm, classification, regression, integr...
# 37997    [penalized, regression, parameter, coefficient...
# 2399     [algorithm, structure, reconstructs, subroutin...
#                                ...
# 7224     [increasingly, classifiers, vulnerable, advers...
# 21311    [challenge, emergence, intelligence, principle...
# 9375     [probabilistic, inference, procedures, painsta...
# 16246    [generation, summarises, biography, selecting,...
# 23020    [correlated, component, dmochowski, investigat...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8658 words.
# Out of those 4598 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="922a78ba-cfac-430a-a3cd-e762c236b5cc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("922a78ba-cfac-430a-a3cd-e762c236b5cc")) {                    Plotly.newPlot(                        "922a78ba-cfac-430a-a3cd-e762c236b5cc",                        [{"x":["represent","information","phenotypic","components","scattered","efficiency","interpretability","variation","clinically","neuroimaging","penalties","nonetheless","relevance","interpret","extension","component","resolution","structured","regularization","intelligible","accounting","unstructured","interpretable","optimization","dimensional","hypothesized","population","exploratory","alternatives","different","essential","framework","structure","incorporation","versatility","combining","approaches","regarding","therefore","demonstrate","variability","principal","autonomous","representation","introduce","exhaustive","algorithm","experiments","representations","variations","performing","classification","detection","scenarios","detecting","furthermore","exploiting","motivated","classifiers","traversable","properties","background","algorithms","conditions","development","characterize","assumption","evaluation","implemented","interface","strategies","unprecedented","description","versatile","experimental","carefully","parameter","selection","regression","integrated","comparisons","decomposition","available","predictor","neighboring","approximator","solutions","supplement","coefficients","penalized","difference","subroutine","outperforms","comparison","reconstructs","currently","empirical","constraint","benchmarks","extensive","dependence","incremental","generator","situations","directions","discriminator","perspective","divergences","necessarily","equilibrium","gradients","restrictive","distribution","approaching","contributes","trajectories","counterexamples","minimization","divergence","providing","parameters","generative","adversarial","criterion","equilibria","specifically","distributions","iteration","composition","derivation","expensive","theoretical","variables","dimensions","applications","benchmark","functions","acquisition","challenging","objective","optimizing","infeasible","consistently","deficient","partitioned","efficient","complexity","synthetic","impossible","boundaries","consistent","theoretic","reasonably","logarithm","recovering","important","performance","simulations","proportional","locations","autoencoders","especially","nevertheless","sequences","recurrent","sentences","quantitative","generating","hierarchical","successful","translation","augmenting","translations","correspond","application","technique","propagate","augmented","characters","autoencoder","intermediate","engineering","relocalization","convolutional","uncertainty","approximately","dissimilar","additional","optimisation","implementation","modelling","localization","appearance","monocular","arbitrarily","approximating","approximated","arbitrary","estimates","continuity"],"y":[111,694,0,115,4,146,16,48,7,1,10,3,31,23,70,91,113,104,71,1,8,17,28,302,177,2,45,6,33,770,71,562,350,4,3,95,423,26,142,535,30,33,51,343,336,17,767,627,226,79,68,535,364,83,69,155,67,57,107,1,200,75,581,130,126,51,66,260,83,29,84,15,69,4,340,36,105,152,108,49,27,55,290,12,16,0,153,2,39,5,57,3,266,139,6,62,138,84,105,175,36,21,29,46,57,14,67,1,20,10,23,8,214,8,13,36,1,63,12,78,242,138,102,46,4,184,121,40,41,8,58,167,118,38,395,197,210,41,268,143,45,9,35,2,3,368,246,128,14,43,91,52,8,3,24,327,829,43,12,43,18,129,14,95,117,62,74,89,101,72,115,5,21,35,252,248,14,41,30,20,33,58,4,385,79,28,3,116,17,121,51,62,79,22,11,11,12,78,67,4],"type":"bar"},{"x":["represent","information","phenotypic","components","scattered","efficiency ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4598,), (4598, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8041666666666667

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.5);'>Demystifying</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Information</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Theoretic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Clustering</span> <br/><br/><span style=''>We</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>novel</span> <span style=''>method</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>clustering</span> <span style=''>data</span> <span style=''>which</span> <span style=''>is</span> <span style=''>grounded</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>information</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>theoretic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>principles</span> <span style=''>and</span> <span style=''>requires</span> <span style=''>no</span> <span style='background-color:rgba(255, 0, 0, 0.4571428571428571);'>parametric</span> <span style='background-color:rgba(255, 0, 0, 0.4074074074074074);'>assumptions</span> <span style=''>Previous</span> <span style=''>attempts</span> <span style=''>to</span> <span style=''>use</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>information</span> <span style=''>theory</span> <span style=''>to</span> <span style=''>define</span> <span style=''>clusters</span> <span style=''>in</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>assumption</span> <span style=''>free</span> <span style=''>way</span> <span style=''>are</span> <span style=''>based</span> <span style=''>on</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>maximizing</span> <span style=''>mutual</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>information</span> <span style=''>between</span> <span style=''>data</span> <span style=''>and</span> <span style=''>cluster</span> <span style=''>labels</span> <span style=''>We</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>demonstrate</span> <span style=''>that</span> <span style=''>this</span> <span style='background-color:rgba(0, 255, 0, 0.4285714285714285);'>intuition</span> <span style=''>suffers</span> <span style=''>from</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>fundamental</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>conceptual</span> <span style=''>flaw</span> <span style=''>that</span> <span style=''>causes</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>clustering</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>performance</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.6000000000000001);'>deteriorate</span> <span style=''>as</span> <span style=''>the</span> <span style=''>amount</span> <span style=''>of</span> <span style=''>data</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>increases</span> <span style=''>Instead</span> <span style=''>we</span> <span style=''>return</span> <span style=''>to</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.6000000000000001);'>axiomatic</span> <span style='background-color:rgba(0, 255, 0, 0.33333333333333337);'>foundations</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>information</span> <span style=''>theory</span> <span style=''>to</span> <span style=''>define</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3647058823529412);'>meaningful</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>clustering</span> <span style=''>measure</span> <span style=''>based</span> <span style=''>on</span> <span style=''>the</span> <span style=''>notion</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>consistency</span> <span style=''>under</span> <span style=''>coarse</span> <span style=''>graining</span> <span sty ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Spectral</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Ergodicity</span> <span style=''>in</span> <span style=''>Deep</span> <span style=''>Learning</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Architectures</span> <span style=''>via</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Surrogate</span> <span style=''>Random</span> <span style=''>Matrices</span> <br/><br/><span style=''>In</span> <span style=''>this</span> <span style=''>work</span> <span style=''>a</span> <span style=''>novel</span> <span style=''>method</span> <span style=''>to</span> <span style=''>quantify</span> <span style=''>spectral</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>ergodicity</span> <span style=''>for</span> <span style=''>random</span> <span style=''>matrices</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>presented</span> <span style=''>The</span> <span style=''>new</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>methodology</span> <span style=''>combines</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approaches</span> <span style=''>rooted</span> <span style=''>in</span> <span style=''>the</span> <span style=''>metrics</span> <span style=''>of</span> <span style=''>Thirumalai</span> <span style=''>Mountain</span> <span style=''>(TM)</span> <span style=''>and</span> <span style=''>Kullbach</span> <span style=''>Leibler</span> <span style=''>(KL)</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>divergence</span> <span style=''>The</span> <span style=''>method</span> <span style=''>is</span> <span style=''>applied</span> <span style=''>to</span> <span style=''>a</span> <span style=''>general</span> <span style=''>study</span> <span style=''>of</span> <span style=''>deep</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>recurrent</span> <span style=''>neural</span> <span style=''>networks</span> <span style=''>via</span> <span style=''>the</span> <span style=''>analysis</span> <span style=''>of</span> <span style=''>random</span> <span style=''>matrix</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>ensembles</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>mimicking</span> <span style=''>typical</span> <span style=''>weight</span> <span style=''>matrices</span> <span style=''>of</span> <span style=''>those</span> <span style=''>systems</span> <span style=''>In</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>particular</span> <span style=''>we</span> <span style=''>examine</span> <span style=''>circular</span> <span style=''>random</span> <span style=''>matrix</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>ensembles</span> <span style=''>circular</span> <span style=''>unitary</span> <span style=''>ensemble</span> <span style=''>(CUE)</span> <span style=''>circular</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>orthogonal</span> <span style=''>ensemble</span> <span style=''>(COE)</span> <span style=''>and</span> <span style=''>circular</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>symplectic</span> <span style=''>ensemble</span> <span style=''>(CSE)</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Eigenvalue</span> <span style=''>spectra</span> <span style=''>and</span> <span style=''>spectral</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>ergodicity</span> <span style=''>are</span> <span style=''>computed</span> <span style=''>for</span> <span style=''>those</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>ensembles</span> <span style=''>as</span> <span style=''>a</span> <span style=''>function</span> <span style=''>of</span> <span style=''>network</span> <span style=''>size</span> <span style=''>It</span> <span style=''>is</span> <span style=''>observed</span> <span style=''>that</span> <span style=''>as</span> <span style=''>the</span> <span style=''>matrix</spa ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Approximate</span> <span style='background-color:rgba(255, 0, 0, 0.32299741602067183);'>Stochastic</span> <span style='background-color:rgba(255, 0, 0, 0.33333333333333337);'>Subgradient</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Estimation</span> <span style=''>Training</span> <span style=''>for</span> <span style=''>Support</span> <span style=''>Vector</span> <span style=''>Machines</span> <br/><br/><span style='background-color:rgba(255, 0, 0, 0.33333333333333337);'>Subgradient</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>for</span> <span style=''>training</span> <span style=''>support</span> <span style=''>vector</span> <span style=''>machines</span> <span style=''>have</span> <span style=''>been</span> <span style=''>quite</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>successful</span> <span style=''>for</span> <span style=''>solving</span> <span style=''>large</span> <span style=''>scale</span> <span style=''>and</span> <span style=''>online</span> <span style=''>learning</span> <span style=''>problems</span> <span style=''>However</span> <span style=''>they</span> <span style=''>have</span> <span style=''>been</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>restricted</span> <span style=''>to</span> <span style=''>linear</span> <span style=''>kernels</span> <span style=''>and</span> <span style=''>strongly</span> <span style=''>convex</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>formulations</span> <span style=''>This</span> <span style=''>paper</span> <span style='background-color:rgba(0, 255, 0, 0.5294117647058822);'>describes</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>efficient</span> <span style='background-color:rgba(255, 0, 0, 0.33333333333333337);'>subgradient</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approaches</span> <span style=''>without</span> <span style=''>such</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>limitations</span> <span style=''>Our</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approaches</span> <span style=''>make</span> <span style=''>use</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.4000000000000001);'>randomized</span> <span style=''>low</span> <span style='background-color:rgba(255, 0, 0, 0.35283363802559425);'>dimensional</span> <span style='background-color:rgba(255, 0, 0, 0.5344827586206897);'>approximations</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>nonlinear</span> <span style=''>kernels</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>minimization</span> <span style=''>of</span> <span style=''>a</span> <span style=''>reduced</span> <span style=''>primal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>formulation</span> <span style=''>using</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>based</span> <span style=''>on</span> <span style=''>robust</span> <span style='background-color:rgba(255, 0, 0, 0.32299741602067183);'>stochastic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approximation</span> <span style=''>which</span> <span style=''>do</span> <span style=''>not</span> <span style=''>require</span> <span style=''>strong</span> <span style='background-color:rgba(255, 0, 0, 0.6);'>convexity</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Experiments</span> <span style='background-color:rgba(255, 0, 0, 0.37234042553191493);'>illustrate</span> <span style=''>that</span> <span style=''>our</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approaches</span> <span style=''>produce</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>solutions</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.320987654320987 ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>DCFNet</span> <span style=''>Deep</span> <span style=''>Neural</span> <span style=''>Network</span> <span style=''>with</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Decomposed</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Convolutional</span> <span style=''>Filters</span> <br/><br/><span style=''>Filters</span> <span style=''>in</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Convolutional</span> <span style=''>Neural</span> <span style=''>Network</span> <span style=''>(CNN)</span> <span style=''>contain</span> <span style=''>model</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parameters</span> <span style=''>learned</span> <span style=''>from</span> <span style=''>enormous</span> <span style=''>amounts</span> <span style=''>of</span> <span style=''>data</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>suggest</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>decompose</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>convolutional</span> <span style=''>filters</span> <span style=''>in</span> <span style=''>CNN</span> <span style=''>as</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>truncated</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>expansion</span> <span style=''>with</span> <span style=''>pre</span> <span style=''>fixed</span> <span style=''>bases</span> <span style=''>namely</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Decomposed</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Convolutional</span> <span style=''>Filters</span> <span style=''>network</span> <span style=''>(DCFNet)</span> <span style=''>where</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>expansion</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>coefficients</span> <span style=''>remain</span> <span style=''>learned</span> <span style=''>from</span> <span style=''>data</span> <span style=''>Such</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structure</span> <span style=''>not</span> <span style=''>only</span> <span style=''>reduces</span> <span style=''>the</span> <span style=''>number</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>trainable</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parameters</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>computation</span> <span style=''>but</span> <span style=''>also</span> <span style=''>imposes</span> <span style=''>filter</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regularity</span> <span style=''>by</span> <span style=''>bases</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>truncation</span> <span style=''>Through</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>extensive</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>experiments</span> <span style=''>we</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>consistently</span> <span style=''>observe</span> <span style=''>that</span> <span style=''>DCFNet</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>maintains</span> <span style=''>accuracy</span> <span style=''>for</span> <span style=''>image</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classification</span> <span style=''>tasks</span> <span style=''>with</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>significant</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>reduction</span> <span style=''>of</span> <span style=''>model</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parameters</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>particularly</span> <span style=''>w ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	evaluation (0.09177550300035298)
# 	automatic (0.06706671373102718)
# 	information (0.24496999647017295)
# 	processing (0.10377691493116838)
# 	architecture (0.08365690081186022)
# 	segmentation (0.07589128132721497)
# 	detection (0.12848570420049418)
# 	different (0.27179668196258383)
# 	recognition (0.13942816801976704)
# 	convolutional (0.13589834098129192)
#
# Some Statistics words are:
# 	convergence (0.11947127605490594)
# 	statistical (0.15353329944077276)
# 	variables (0.1337061514997458)
# 	theoretical (0.16217590238942553)
# 	estimation (0.17895271987798678)
# 	distribution (0.19572953736654805)
# 	dimensional (0.18810371123538383)
# 	inference (0.20386375190645653)
# 	algorithm (0.41484494153533297)
# 	regression (0.1840366039654296)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="a87a406e-1433-4fce-ac3b-fc8e1add8087" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a87a406e-1433-4fce-ac3b-fc8e1add8087")) {                    Plotly.newPlot(                        "a87a406e-1433-4fce-ac3b-fc8e1add8087",                        [{"x":["represent","information","phenotypic","components","scattered","efficiency","interpretability","variation","clinically","neuroimaging","penalties","nonetheless","relevance","interpret","extension","component","resolution","structured","regularization","intelligible","accounting","unstructured","interpretable","optimization","dimensional","hypothesized","population","exploratory","alternatives","different","essential","framework","structure","incorporation","versatility","combining","approaches","regarding","therefore","demonstrate","variability","principal","autonomous","representation","introduce","exhaustive","algorithm","experiments","representations","variations","performing","classification","detection","scenarios","detecting","furthermore","exploiting","motivated","classifiers","traversable","properties","background","algorithms","conditions","development","characterize","assumption","evaluation","implemented","interface","strategies","unprecedented","description","versatile","experimental","carefully","parameter","selection","regression","integrated","comparisons","decomposition","available","predictor","neighboring","approximator","solutions","supplement","coefficients","penalized","difference","subroutine","outperforms","comparison","reconstructs","currently","empirical","constraint","benchmarks","extensive","dependence","incremental","generator","situations","directions","discriminator","perspective","divergences","necessarily","equilibrium","gradients","restrictive","distribution","approaching","contributes","trajectories","counterexamples","minimization","divergence","providing","parameters","generative","adversarial","criterion","equilibria","specifically","distributions","iteration","composition","derivation","expensive","theoretical","variables","dimensions","applications","benchmark","functions","acquisition","challenging","objective","optimizing","infeasible","consistently","deficient","partitioned","efficient","complexity","synthetic","impossible","boundaries","consistent","theoretic","reasonably","logarithm","recovering","important","performance","simulations","proportional","locations","autoencoders","especially","nevertheless","sequences","recurrent","sentences","quantitative","generating","hierarchical","successful","translation","augmenting","translations","correspond","application","technique","propagate","augmented","characters","autoencoder","intermediate","engineering","relocalization","convolutional","uncertainty","approximately","dissimilar","additional","optimisation","implementation","modelling","localization","appearance","monocular","arbitrarily","approximating","approximated","arbitrary","estimates","continuity","precision","continuous","construction","activations","approximate","following","dimension","approximation","expressive","accurately","leveraging","significantly","interestingly","utilizing","considerably","resulting","conditional","independence","comparable","complementing","guaranteed","parallelization","computational","achieving","advantages","scalability","centralized","computing","advantage","performances","predictive","analyzing","estimating","operating","diagnostic","confirmed","evaluating","characteristic","tournament","preserves","estimation","validation","elimination","discretization","limitations","probability","represented","truncated","multiplicative","relationships","potentials","introduces","alternative","restr ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	phenotypic
# 	approximator
# 	irreducible
# 	graphically
# 	precautions
# 	judiciously
# 	thermostats
# 	barcelona
# 	martingale
# 	convolved
# 	precisionk
# 	confirming
# 	bonferroni
# 	exception
# 	manifested
# 	nontrivially
# 	locomotion
# 	intermittent
# 	stimulated
# 	orthogonality
# Some words which never appear in Statistics papers:
# 	relocalization
# 	monocular
# 	attenuation
# 	perceiving
# 	contrasts
# 	isointense
# 	compilations
# 	propositional
# 	encodings
# 	simplifications
# 	artefacts
# 	myocardial
# 	substructures
# 	middleware
# 	exceptionally
# 	attractors
# 	externally
# 	descriptive
# 	certainty
# 	marginalizes

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0369290573372204e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7408333333333333
